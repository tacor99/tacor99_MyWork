# %%
from IPython.display import Image

Image(filename='question1.jpg') 
Image(filename='question1.jpg')

# %% [markdown]
# ## 105年3月實作題第二題

# %%
r=3
c=2
m=3

# %%
a=[[11,12],[21,22],[31,32]]

# %%
b=a[::-1]

# %%
d=[0]
for i in range(c):
    d[i]=[j[i] for j in a]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-0b07a5643d33> in <module>
#       1 d=[0]
#       2 for i in range(c):
# ----> 3     d[i]=[j[i] for j in a]
#       4
#
# IndexError: list assignment index out of range

# %%
i = [1, 2, 3, 5, 8, 13]
j = []
k = 0

for l in i:
    j[k] = l
    k += 1

print j

for l in i:
    j.append(l)
