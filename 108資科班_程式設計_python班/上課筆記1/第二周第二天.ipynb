# %%
# %matplotlib inline

from IPython.display import display, Markdown, YouTubeVideo, Image

a=input('你幾歲?')
m=f'## 你是{a}歲'
display(Markdown(m))
display(YouTubeVideo('6SkbNlWMG5w'))
display(Image('65475277.jpg'))
# Out:
# 你幾歲?3
# ## 你是3歲

# %%
# %cat
# Out:
# UsageError: Line magic function `%cat` not found.

# %%
# !type
# Out:
# 命令語法不正確。

# %%
# !type "第二周第一天.ipynb"
# Out:
# 系統找不到指定的檔案。

# %%
weekly_url="http://www.marieclaire.com.tw/love-sex/astrology/43867"

# %%
web=requests.get(weekly_url)
